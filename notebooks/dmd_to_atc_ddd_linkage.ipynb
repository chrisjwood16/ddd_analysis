# %% [markdown]
# # dm+d to ATC DDD linkage

# %% [markdown]
# To enable linking SCMD data to WHO DDDs we need to be able to link reliably from VMP code to an ATC code + a form in the WHO format.
# The NHS BSA produce a lookup file to link individual VMP codes to ATC codes (using a one-to-one relationship).
# In the same file the NHS BSA also provide some pre-specified DDDs - although the methodology behind this and the completeness is unclear.
# This notebook sets out to set out a method to reliably link VMPs to WHO DDDs.

# %%
import pandas as pd
import requests
from ebmdatalab import bq
import os

# %% [markdown]
# ### Converting route

# %% [markdown]
# The WHO DDD files have different DDDs for different routes of administration - the route is identified using the ```adm_code```.
#
# We can show a list of distinct `adm_code` used in the WHO DDD files.

# %%
sql = f"""
    SELECT DISTINCT
      adm_code,
      COUNT(atc_code) AS count
    FROM `ebmdatalab.scmd.ddd`
    GROUP BY adm_code
    ORDER BY count DESC
"""
# Define the CSV path for caching the results.
csv_path = os.path.join('..', 'data', 'unique_adm_code.csv')

# Use the cached_read function from the bq library to run the query.
unique_adm_code = bq.cached_read(sql, csv_path=csv_path)

unique_adm_code
# Out:
#             adm_code  count
# 0                  O   1642
# 1                  P    782
# 2                  R     79
# 3                  N     38
# 4                  V     37
# 5     Inhal.solution     25
# 6       Inhal.powder     23
# 7      Inhal.aerosol     23
# 8                NaN     17
# 9                 SL     16
# 10                TD     14
# 11           implant      5
# 12          ointment      2
# 13      intravesical      2
# 14      oral aerosol      2
# 15             Inhal      1
# 16           lamella      1
# 17          urethral      1
# 18       Chewing gum      1
# 19    s.c. implant        1
# 20  Instill.solution      1

# %% [markdown]
# The dm+d also holds similar data on routes. The `ontologyformroute` table has the most detailed information with a description of the formulation, then a full stop, then the route - for example - `tablet.oral`
#
# We can show a list of distinct `ontologyformroute` descriptions:

# %%
sql = f"""
    SELECT DISTINCT
      ofr.descr
    FROM `ebmdatalab.dmd.vmp` vmp
    LEFT JOIN `ebmdatalab.dmd.ont` ont ON vmp.id = ont.vmp
    LEFT JOIN `ebmdatalab.dmd.ontformroute` ofr ON ont.form = ofr.cd    
    ORDER BY ofr.descr ASC
"""
# Define the CSV path for caching the results.
csv_path = os.path.join('..', 'data', 'unique_ofr.csv')

# Use the cached_read function from the bq library to run the query.
unique_ofr = bq.cached_read(sql, csv_path=csv_path)

unique_ofr
# Out:
#                                     descr
# 0                                     NaN
# 1          bladderirrigation.intravesical
# 2                            capsule.oral
# 3                         capsule.vaginal
# 4                    capsulechewable.oral
# ..                                    ...
# 329  vapourinhalationimpregnatedpad.nasal
# 330     vapourinhalationliquid.inhalation
# 331          vapourinhalationliquid.nasal
# 332        vapourinhalationointment.nasal
# 333        vapourinhalationsolution.nasal
#
# [334 rows x 1 columns]

# %% [markdown]
# To link between the WHO `adm_code` and the dm+d `ontologyformroute` we need to create a map.
#
# Use of SQL code to do this makes the methodology clearer and easy to adapt in future.
#
# Matching for many routes can simply be done based on matching the route part of the dm+d `ontologyformroute` to the appropriate `adm_code` for example matching all `.oral` products to the `adm_code` `O`
#
# A small number require more careful matching, for example, looking at the `implant` `adm_code` we can see this actually relates to implants which are administered by subcutaneous injection - so we need to specifically match `implant.subcutaneous` to `implant` while the rest of the `subcutaneous` route will be matched to `P`.
#
# There are a large number of routes in the dm+d which don't have DDDs defined by the WHO. We can disguard these from matching. A small percentage of these may be able to be matched at a later stage following a closer look at missing data.

# %%
sql = f"""
    SELECT DISTINCT
      ofr.descr AS dmd_ofr,
      SPLIT(ofr.descr, '.')[OFFSET(1)] AS dmd_r,
      CASE
        WHEN ofr.descr = 'implant.subcutaneous' THEN 'implant'
        WHEN ofr.descr = 'pressurizedinhalation.inhalation' THEN 'Inhal.aerosol'
        WHEN ofr.descr = 'powderinhalation.inhalation' THEN 'Inhal.powder'
        WHEN ofr.descr = 'solutionnebuliser.inhalation' THEN 'Inhal.solution'
        WHEN ofr.descr = 'dispersionnebuliser.inhalation' THEN 'Inhal.solution' -- amikacin liposomal
        WHEN ofr.descr = 'inhalationsolution.inhalation' THEN 'Inhal.solution' -- mist inhalers - e.g. tiotropium respimat
        WHEN ofr.descr = 'suspensionnebuliser.inhalation' THEN 'Inhal.solution' -- steroid nebs
        WHEN ofr.descr = 'medicatedchewing-gum.oromucosal' THEN 'Chewing gum' -- nicotine
        WHEN ofr.descr = 'solution.oromucosal' THEN 'SL' -- midazolam oromucosal
        WHEN ofr.descr = 'tabletsublingual.oromucosal' THEN 'SL'
        WHEN ofr.descr = 'lozenge.oromucosal' THEN 'SL' -- fentanyl lozenge
        WHEN ofr.descr = 'lyophilisate.oromucosal' THEN 'SL' -- buprenorphine
        WHEN ofr.descr = 'filmsublingual.oromucosal' THEN 'SL' -- buprenorphine
        WHEN ofr.descr = 'vapour.oromucosal' THEN 'Inhal' -- nicotine inhalator - to match ATC
        WHEN ofr.descr LIKE '%.oral' THEN 'O'
        WHEN ofr.descr LIKE '%.gastroenteral' THEN 'O'
        WHEN ofr.descr LIKE '%.intravenous' THEN 'P'
        WHEN ofr.descr LIKE '%.intramuscular%' THEN 'P'
        WHEN ofr.descr LIKE '%.subcutaneous' THEN 'P'
        WHEN ofr.descr LIKE '%.intracavernous' THEN 'P'
        WHEN ofr.descr LIKE '%.intracardiac' THEN 'P'   
        WHEN ofr.descr LIKE '%.intracoronary' THEN 'P'  
        WHEN ofr.descr LIKE '%.vaginal' THEN 'V'
        WHEN ofr.descr LIKE '%.rectal' THEN 'R'
        WHEN ofr.descr LIKE '%.submucosalrectal' THEN 'R'
        WHEN ofr.descr LIKE '%.nasal' THEN 'N'
        WHEN ofr.descr LIKE '%.buccal' THEN 'SL'
        WHEN ofr.descr LIKE '%.sublingual' THEN 'SL'
        WHEN ofr.descr LIKE '%.transdermal' THEN 'TD'
        WHEN ofr.descr LIKE '%.urethral' THEN 'urethral'   
        WHEN ofr.descr LIKE '%.intravesical' THEN 'intravesical'
      END AS who_route
      FROM `ebmdatalab.dmd.vmp` vmp
    LEFT JOIN dmd.ont ont ON vmp.id = ont.vmp
    LEFT JOIN dmd.ontformroute ofr ON ont.form = ofr.cd
    LEFT JOIN dmd.droute droute ON vmp.id = droute.vmp
    LEFT JOIN dmd.route route ON droute.route = route.cd
    WHERE route.descr IS NOT NULL 
    AND ofr.descr IS NOT NULL
    AND ofr.descr NOT LIKE '%.auricular' -- eye drops don't seem to have DDDs
    AND ofr.descr NOT LIKE '%.bodycavity' -- ??
    AND ofr.descr NOT LIKE '%.cutaneous' -- no DDDs
    AND ofr.descr NOT LIKE '%.dental' -- mostly sodium fluoride toothpaste, chlorhexidine mouthwash - no obvious route match
    AND ofr.descr NOT LIKE '%.endocervical' -- no obvious route match
    AND ofr.descr NOT LIKE '%.endosinusial'-- no obvious route match
    AND ofr.descr NOT LIKE '%.endotracheopulmonary' -- possibly match on inhalation, but not much here with DDDs
    AND ofr.descr NOT LIKE '%.epidural' -- no obvious route match/ no relevent DDDs e.g. bupivacaine
    AND ofr.descr NOT LIKE '%.epilesional'-- no obvious route match
    AND ofr.descr NOT LIKE '%.extraamniotic'-- no obvious route match
    AND ofr.descr NOT LIKE '%.extracorporeal'-- no obvious route match
    AND ofr.descr NOT LIKE '%.gingival'-- no obvious route match
    AND ofr.descr NOT LIKE '%.haemodialysis'-- no obvious route match
    AND ofr.descr NOT LIKE '%.haemofiltration'-- no obvious route match
    AND ofr.descr NOT LIKE '%.implantation'-- no obvious route match. Not to be confused with subcutaneous implants
    AND ofr.descr NOT LIKE '%.infiltration'-- no obvious route match
    AND ofr.descr NOT LIKE '%.scalp'-- no obvious route match
    AND ofr.descr NOT LIKE '%.ophthalmic'-- no obvious route match
    AND ofr.descr NOT LIKE '%.opthalmic'-- typo for above
    AND ofr.descr NOT LIKE '%.intestinal'-- levodopa gels for Parkinson's disease
    AND ofr.descr NOT LIKE '%.intraarterial'-- contrast media. A few drugs but the probably also have a more common P route.
    AND ofr.descr NOT LIKE '%.intraarticular'-- limited interest
    AND ofr.descr NOT LIKE '%.intrabursal'-- limited interest
    AND ofr.descr NOT LIKE '%.intracameral'-- niche
    AND ofr.descr NOT LIKE '%.intracerebroventricular'-- niche
    AND ofr.descr NOT LIKE '%.intracholangiopancreatic'-- contrast media
    AND ofr.descr NOT LIKE '%.intradermal'-- limited interest - a few vaccines - probably no DDDs
    AND ofr.descr NOT LIKE '%.intradiscal'-- niche
    AND ofr.descr NOT LIKE '%.intraepidermal'-- skin prick tests
    AND ofr.descr NOT LIKE '%.intraglandular'-- contrast / Botox
    AND ofr.descr NOT LIKE '%.intralesional'-- contrast media. A few drugs but the probably also have a more common P route.
    AND ofr.descr NOT LIKE '%.intraocular'-- no obvious route match
    AND ofr.descr NOT LIKE '%.intraosseous'-- A few specific drugs but the probably also have a more common P route.
    AND ofr.descr NOT LIKE '%.intraperitoneal'-- no obvious route match
    AND ofr.descr NOT LIKE '%.intrapleural'-- niche
    AND ofr.descr NOT LIKE '%.intraputaminal'-- putamen = part of brain. Very niche - 1 product - gene therapy
    AND ofr.descr NOT LIKE '%.intrathecal'-- A few specific drugs but the probably also have a more common P route.
    AND ofr.descr NOT LIKE '%.intratumoral'-- niche
    AND ofr.descr NOT LIKE '%.intrauterine'-- no obvious route
    AND ofr.descr NOT LIKE '%.intraventricular cardiac'-- niche
    AND ofr.descr NOT LIKE '%.intravitreal'-- no obvious route. No DDDs for those of interest.
    AND ofr.descr NOT LIKE '%.iontophoresis'-- no obvious route
    AND ofr.descr NOT LIKE '%.linelock'-- no obvious route
    AND ofr.descr NOT LIKE '%.ocular'-- no obvious route
    AND ofr.descr NOT LIKE '%.periarticular'-- no obvious route
    AND ofr.descr NOT LIKE '%.peribulbar ocular'-- no obvious route
    AND ofr.descr NOT LIKE '%.perilesional'-- no obvious route
    AND ofr.descr NOT LIKE '%.perineural'-- no obvious route, niche
    AND ofr.descr NOT LIKE '%.peritumoral'-- no obvious route
    AND ofr.descr NOT LIKE '%.regionalperfusion'-- no obvious route
    AND ofr.descr NOT LIKE '%.subconjunctival'-- no obvious route
    AND ofr.descr NOT LIKE '%.submucosal'-- no obvious route, small number of products with a more common P route
    AND ofr.descr NOT LIKE '%.subretinal'-- no obvious route
    AND ofr.descr != 'gasinhalation.inhalation' -- medical gases
    AND ofr.descr != 'vapourinhalationliquid.inhalation' -- inhaled anaesthetics
    AND ofr.descr != 'vapourinhalation.inhalation' -- only 1 product - Benzoin compound tincture
    AND ofr.descr != 'impregnatedcigarette.inhalation' -- no DDDs
    AND ofr.descr NOT IN ('gargle.oromucosal', 'gel.oromucosal', 'homeopathicpillule.oromucosal', 'liquid.oromucosal', 'liquidspray.oromucosal', 'mouthwash.oromucosal', 'paste.oromucosal', 'homeopathictablet.oromucosal', 'pastille.oromucosal', 'solutionspray.oromucosal', 'suspension.oromucosal', 'suspensionspray.oromucosal', 'tabletmuco-adhesive.oromucosal', 'vapour.oromucosal') -- no DDDs
    ORDER BY who_route, dmd_r ASC
"""
# Define the CSV path for caching the results.
csv_path = os.path.join('..', 'data', 'dmd_to_atc_route.csv')

# Use the cached_read function from the bq library to run the query.
dmd_to_atc_route = bq.cached_read(sql, csv_path=csv_path)

dmd_to_atc_route
# Out:
#                               dmd_ofr         dmd_r       who_route
# 0     medicatedchewing-gum.oromucosal    oromucosal     Chewing gum
# 1    pressurizedinhalation.inhalation    inhalation   Inhal.aerosol
# 2         powderinhalation.inhalation    inhalation    Inhal.powder
# 3        solutionnebuliser.inhalation    inhalation  Inhal.solution
# 4      dispersionnebuliser.inhalation    inhalation  Inhal.solution
# ..                                ...           ...             ...
# 150   solutionirrigation.intravesical  intravesical    intravesical
# 151             solution.intravesical  intravesical    intravesical
# 152                    stick.urethral      urethral        urethral
# 153                      gel.urethral      urethral        urethral
# 154                 ointment.urethral      urethral        urethral
#
# [155 rows x 3 columns]

# %% [markdown]
# The result of this is saved as a view within BigQuery - `dmd_to_atc_route`

# %% [markdown]
# ### Checking for multiple routes
# Now that we have a mapping, we can link this to VMP codes and look for any VMPs which have multiple associated routes - as this will cause issues joining to the DDD data.

# %%
sql = f"""
    SELECT 
      vmp.id AS vmp_id,
      vmp.nm AS vmp_nm,
      COUNT(DISTINCT routelookup.who_route) AS distinct_who_route_count
    FROM `ebmdatalab.dmd.vmp` vmp
    LEFT JOIN dmd.ont ont ON vmp.id = ont.vmp
    LEFT JOIN dmd.ontformroute ofr ON ont.form = ofr.cd
    INNER JOIN `dmd.vpi_to_atc_and_ddd` atclookup ON vmp.id = atclookup.VPID
    LEFT JOIN dmd.unitofmeasure uom ON atclookup.DDD_UOMCD = uom.cd
    INNER JOIN `scmd_dmd_views.dmd_to_atc_route` routelookup ON ofr.descr = routelookup.dmd_ofr
    INNER JOIN `scmd.ddd` ddd ON atclookup.ATC = ddd.atc_code AND routelookup.who_route = ddd.adm_code
    GROUP BY vmp.id, vmp.nm
    HAVING distinct_who_route_count > 1
"""
# Define the CSV path for caching the results.
csv_path = os.path.join('..', 'data', 'multi_route_products.csv')

# Use the cached_read function from the bq library to run the query.
multi_route_products = bq.cached_read(sql, csv_path=csv_path)

multi_route_products
# Out:
#               vmp_id                                             vmp_nm  \
# 0  39709011000001102                       Progesterone 400mg pessaries
# 1  41760311000001104  Colistimethate 1million unit powder for soluti...
# 2  41760411000001106  Colistimethate 500,000unit powder for solution...
# 3  39708911000001106                       Progesterone 200mg pessaries
# 4  36015811000001103  Phytomenadione 2mg/0.2ml solution for injectio...
# 5   4078411000001107  Paraldehyde 100% solution for injection 5ml am...
# 6   4638311000001106  Colistimethate 2million unit powder for soluti...
# 7  13821411000001101  Caffeine citrate 10mg/1ml solution for infusio...
# 8  20532611000001105  Caffeine citrate 20mg/1ml solution for infusio...
#
#    distinct_who_route_count
# 0                         2
# 1                         2
# 2                         2
# 3                         2
# 4                         2
# 5                         2
# 6                         2
# 7                         2
# 8                         2

# %% [markdown]
# A review of the product information for these products show that the are licensed for use by multiple routes. A pragmatic decision can be made to decide the most likely route.
#
# A table to manually map theses can be created like follows:

# %%
sql = f"""
    SELECT *
    FROM `ebmdatalab.chris.vmp_single_route_identifier`
"""
# Define the CSV path for caching the results.
csv_path = os.path.join('..', 'data', 'vmp_single_route_identifier.csv')

# Use the cached_read function from the bq library to run the query.
vmp_single_route_identifier = bq.cached_read(sql, csv_path=csv_path)

vmp_single_route_identifier
# Out:
#               vmp_id route
# 0  39709011000001102     V
# 1  39708911000001106     V
# 2  36015811000001103     P
# 3   4078411000001107     P
# 4  41760411000001106     P
# 5   4638311000001106     P
# 6  41760311000001104     P
# 7  20532611000001105     P
# 8  13821411000001101     P

# %% [markdown]
# With this fix we can create a mapping table of one-to-one dm+d route to WHO route.

# %%
sql = f"""
    SELECT DISTINCT
      vmp.id AS vmp_id,
      vmp.nm AS vmp_nm,
      COALESCE(sroute.route, routelookup.who_route) AS who_route,
      atclookup.ATC AS atc,
      atclookup.DDD as dmd_DDD,
      uom.descr as dmd_UOM,
      ddd.ddd AS who_ddd,
      ddd.unit_type AS who_UOM,
      ddd.ddd_comment AS who_ddd_comment
    FROM `ebmdatalab.dmd.vmp` vmp
    LEFT JOIN dmd.ont ont ON vmp.id = ont.vmp
    LEFT JOIN dmd.ontformroute ofr ON ont.form = ofr.cd
    INNER JOIN `dmd.vpi_to_atc_and_ddd` atclookup ON vmp.id = atclookup.VPID
    LEFT JOIN dmd.unitofmeasure uom ON atclookup.DDD_UOMCD = uom.cd
    LEFT JOIN chris.vmp_single_route_identifier sroute ON vmp.id = sroute.vmp_id
    INNER JOIN `scmd_dmd_views.dmd_to_atc_route` routelookup ON ofr.descr = routelookup.dmd_ofr
    INNER JOIN `scmd.ddd` ddd ON atclookup.ATC = ddd.atc_code AND COALESCE(sroute.route, routelookup.who_route) = ddd.adm_code
"""
# Define the CSV path for caching the results.
csv_path = os.path.join('..', 'data', 'ddd_joined.csv')

# Use the cached_read function from the bq library to run the query.
ddd_joined = bq.cached_read(sql, csv_path=csv_path)

ddd_joined
# Out:
#                  vmp_id                                             vmp_nm  \
# 0     42372711000001106                         Carvedilol 3.125mg tablets
# 1     42372811000001103                          Carvedilol 6.25mg tablets
# 2     42372511000001101                          Carvedilol 12.5mg tablets
# 3     42372611000001102                            Carvedilol 25mg tablets
# 4     42034011000001101                           Cinnarizine 15mg tablets
# ...                 ...                                                ...
# 9777  17020111000001106  Epoetin theta 10,000units/1ml solution for inj...
# 9778  17020211000001100  Epoetin theta 2,000units/0.5ml solution for in...
# 9779  17020511000001102  Epoetin theta 30,000units/1ml solution for inj...
# 9780  17020311000001108  Epoetin theta 20,000units/1ml solution for inj...
# 9781   4672211000001103  Laronidase 500units/5ml solution for infusion ...
#
#      who_route      atc  dmd_DDD dmd_UOM  who_ddd who_UOM who_ddd_comment
# 0            O  C07AG02     37.5      mg     37.5      mg             NaN
# 1            O  C07AG02     37.5      mg     37.5      mg             NaN
# 2            O  C07AG02     37.5      mg     37.5      mg             NaN
# 3            O  C07AG02     37.5      mg     37.5      mg             NaN
# 4            O  N07CA02     90.0      mg     90.0      mg             NaN
# ...        ...      ...      ...     ...      ...     ...             ...
# 9777         P  B03XA01   1000.0    unit      1.0      TU             NaN
# 9778         P  B03XA01   1000.0    unit      1.0      TU             NaN
# 9779         P  B03XA01   1000.0    unit      1.0      TU             NaN
# 9780         P  B03XA01   1000.0    unit      1.0      TU             NaN
# 9781         P  A16AB05   1000.0    unit      1.0      TU             NaN
#
# [9782 rows x 9 columns]

# %% [markdown]
# ### Compared dm+d DDDs with ATC DDDs

# %% [markdown]
# We can use the dm+d DDDs to validate our matching (where they are given).
# To do this we need to make sure both use the same units. We can add a new column `dmd_ddd_matched` which has the DDD value converted to the same unit as that used for the WHO DDD.

# %%
sql = f"""
    WITH matched_ddds AS (
      SELECT DISTINCT
      vmp.id AS vmp_id,
      vmp.nm AS vmp_nm,
      COALESCE(sroute.route, routelookup.who_route) AS who_route,
      atclookup.ATC AS atc,
      atclookup.DDD as dmd_DDD,
      uom.descr as dmd_UOM,
      CASE
        WHEN uom.descr = 'gram' AND ddd.unit_type = 'g' THEN atclookup.DDD
        WHEN uom.descr = 'mega unit' AND ddd.unit_type = 'MU' THEN atclookup.DDD
        WHEN uom.descr = 'mg' AND ddd.unit_type = 'mg' THEN atclookup.DDD
        WHEN uom.descr = 'mg' AND ddd.unit_type = 'g' THEN atclookup.DDD/1000
        WHEN uom.descr = 'mg' AND ddd.unit_type = 'mcg' THEN atclookup.DDD*1000
        WHEN uom.descr = 'microgram' AND ddd.unit_type = 'mcg' THEN atclookup.DDD
        WHEN uom.descr = 'microgram' AND ddd.unit_type = 'mg' THEN atclookup.DDD/1000
        WHEN uom.descr = 'tablet' AND ddd.unit_type = 'tablet' THEN atclookup.DDD
        WHEN uom.descr = 'unit' AND ddd.unit_type = 'U' THEN atclookup.DDD
        WHEN uom.descr = 'unit' AND ddd.unit_type = 'TU' THEN atclookup.DDD/1000
        WHEN uom.descr = 'unit' AND ddd.unit_type = 'MU' THEN atclookup.DDD/1000000
      END AS dmd_DDD_matched,
      ddd.unit_type AS dmd_UOM_matched,
      ddd.ddd AS who_ddd,
      ddd.unit_type AS who_UOM,
      ddd.ddd_comment AS who_ddd_comment
    FROM `ebmdatalab.dmd.vmp` vmp
    LEFT JOIN dmd.ont ont ON vmp.id = ont.vmp
    LEFT JOIN dmd.ontformroute ofr ON ont.form = ofr.cd
    INNER JOIN `dmd.vpi_to_atc_and_ddd` atclookup ON vmp.id = atclookup.VPID
    LEFT JOIN dmd.unitofmeasure uom ON atclookup.DDD_UOMCD = uom.cd
    LEFT JOIN chris.vmp_single_route_identifier sroute ON vmp.id = sroute.vmp_id
    INNER JOIN `scmd_dmd_views.dmd_to_atc_route` routelookup ON ofr.descr = routelookup.dmd_ofr
    INNER JOIN `scmd.ddd` ddd ON atclookup.ATC = ddd.atc_code AND COALESCE(sroute.route, routelookup.who_route) = ddd.adm_code
    )
    SELECT * FROM matched_ddds
    WHERE dmd_DDD_matched != who_ddd
    ORDER BY atc ASC
"""
# Define the CSV path for caching the results.
csv_path = os.path.join('..', 'data', 'ddd_joined_unmatched.csv')

# Use the cached_read function from the bq library to run the query.
ddd_joined_unmatched = bq.cached_read(sql, csv_path=csv_path)

with pd.option_context('display.max_rows', None):
    display(ddd_joined_unmatched)
# Out:
# Downloading: 100%|█████████████████████████████████████████████████████████████|
#                 vmp_id                                             vmp_nm  \
# 0    35824211000001108   Budesonide 1mg orodispersible tablets sugar free
# 1    40754711000001107  Budesonide 500microgram orodispersible tablets...
# 2    42082711000001102                        Glibenclamide 2.5mg tablets
# 3    42082811000001105                          Glibenclamide 5mg tablets
# 4     8523711000001107                Glibenclamide 5mg/5ml oral solution
# 5     8523911000001109              Glibenclamide 7.5mg/5ml oral solution
# 6     8523811000001104              Glibenclamide 5mg/5ml oral suspension
# 7     8524011000001107            Glibenclamide 7.5mg/5ml oral suspension
# 8    12135811000001104    Glibenclamide 625micrograms/5ml oral suspension
# 9    12135711000001107      Glibenclamide 625micrograms/5ml oral solution
# 10   12135411000001101             Glibenclamide 15mg/5ml oral suspension
# 11   12135311000001108               Glibenclamide 15mg/5ml oral solution
# 12   12135611000001103            Glibenclamide 2.5mg/5ml oral suspension
# 13   12135511000001102              Glibenclamide 2.5mg/5ml oral solution
# 14   37405911000001104  Glibenclamide 600micrograms/ml oral suspension...
# 15   37406011000001107    Glibenclamide 6mg/ml oral suspension sugar free
# 16   11494111000001102  Exenatide 10micrograms/0.04ml solution for inj...
# 17   11494211000001108  Exenatide 5micrograms/0.02ml solution for inje...
# 18   19275411000001107  Exenatide 2mg powder and solvent for prolonged...
# 19   28440211000001102  Exenatide 2mg powder and solvent for prolonged...
# 20   38082811000001104  Exenatide 2mg/0.85ml prolonged-release suspens...
# 21    4119411000001102  Sodium fluoride 2.2mg chewable tablets sugar free
# 22    4119211000001101  Sodium fluoride 1.1mg chewable tablets sugar free
# 23   42017311000001102                      Sodium fluoride 1.1mg tablets
# 24   42017411000001109                      Sodium fluoride 2.2mg tablets
# 25   36052211000001100  Glyceryl trinitrate 2mg modified-release bucca...
# 26   42211111000001100  Glyceryl trinitrate 500microgram sublingual ta...
# 27   42211211000001106  Glyceryl trinitrate 600microgram sublingual ta...
# 28   42211011000001101  Glyceryl trinitrate 300microgram sublingual ta...
# 29   36052311000001108  Glyceryl trinitrate 3mg modified-release bucca...
# 30   36052511000001102  Glyceryl trinitrate 5mg modified-release bucca...
# 31    4557911000001100  Glyceryl trinitrate 1mg modified-release bucca...
# 32   36050311000001109   Isosorbide dinitrate 30mg/dose transdermal spray
# 33   36015411000001100  Phentolamine 10mg/1ml solution for injection a...
# 34   35916711000001105       Testosterone 5mg/24hours transdermal patches
# 35   35916611000001101     Testosterone 2.5mg/24hours transdermal patches
# 36   35916811000001102       Testosterone 6mg/24hours transdermal patches
# 37    9478711000001105  Testosterone 50mg/5g transdermal gel unit dose...
# 38    9186611000001108  Testosterone 50mg/5g transdermal gel unit dose...
# 39   11564011000001106  Testosterone 2% transdermal gel (10mg per actu...
# 40   22155111000001109     Testosterone 2.4mg/24hours transdermal patches
# 41   35025711000001101  Testosterone 16.2mg/g transdermal gel (20.25mg...
# 42   35824911000001104  Testosterone 20mg/g transdermal gel (23mg per ...
# 43   40518511000001101  Testosterone 40.5mg/2.5g transdermal gel unit ...
# 44   42578411000001101  Testosterone 20mg/g transdermal gel (23mg per ...
# 45    3405311000001106                    Estradiol 25microgram pessaries
# 46   36064911000001108  Estradiol 25micrograms/24hours transdermal pat...
# 47   36064911000001108  Estradiol 25micrograms/24hours transdermal pat...
# 48   36065111000001109  Estradiol 40micrograms/24hours transdermal pat...
# 49   36065111000001109  Estradiol 40micrograms/24hours transdermal pat...
# 50   36065511000001100  Estradiol 80micrograms/24hours transdermal pat...
# 51   36065511000001100  Estradiol 80micrograms/24hours transdermal pat...
# 52   36065011000001108  Estradiol 37.5micrograms/24hours transdermal p...
# 53   36065011000001108  Estradiol 37.5micrograms/24hours transdermal p...
# 54   36065411000001104  Estradiol 75micrograms/24hours transdermal pat...
# 55   36065411000001104  Estradiol 75micrograms/24hours transdermal pat...
# 56   36064811000001103  Estradiol 100micrograms/24hours transdermal pa...
# 57   36064811000001103  Estradiol 100micrograms/24hours transdermal pa...
# 58   39112011000001100  Estradiol 50micrograms/24hours transdermal pat...
# 59   39112011000001100  Estradiol 50micrograms/24hours transdermal pat...
# 60   41739711000001100  Estradiol 0.06% transdermal gel (750microgram ...
# 61   41739711000001100  Estradiol 0.06% transdermal gel (750microgram ...
# 62    3664211000001102     Estradiol 500microgram transdermal gel sachets
# 63    3664211000001102     Estradiol 500microgram transdermal gel sachets
# 64    3664111000001108              Estradiol 1mg transdermal gel sachets
# 65    3664111000001108              Estradiol 1mg transdermal gel sachets
# 66   18109911000001108                    Estradiol 10microgram pessaries
# 67   24580611000001102  Estradiol 7.5micrograms/24hours vaginal delive...
# 68   38344311000001108            Estradiol 1.53mg/dose transdermal spray
# 69   38344311000001108            Estradiol 1.53mg/dose transdermal spray
# 70   42297011000001105                         Norethisterone 1mg tablets
# 71   35910611000001103  Betamethasone 4mg/1ml solution for injection a...
# 72   41949011000001107  Erythromycin ethyl succinate 250mg/5ml oral su...
# 73   41948911000001103  Erythromycin ethyl succinate 125mg/5ml oral su...
# 74   41948811000001108        Erythromycin 250mg gastro-resistant tablets
# 75   36064711000001106       Erythromycin 250mg gastro-resistant capsules
# 76   41949411000001103                Erythromycin stearate 500mg tablets
# 77   41949311000001105                Erythromycin stearate 250mg tablets
# 78   41949211000001102  Erythromycin ethyl succinate 500mg/5ml oral su...
# 79   39107211000001106  Erythromycin ethyl succinate 500mg/5ml oral su...
# 80   39107311000001103  Erythromycin ethyl succinate 250mg/5ml oral su...
# 81   41949111000001108         Erythromycin ethyl succinate 500mg tablets
# 82   36564711000001108  Erythromycin ethyl succinate 125mg/5ml oral su...
# 83   41951711000001108                   Methenamine hippurate 1g tablets
# 84    9730811000001105  Amphotericin B (lipid formulation) 50mg powder...
# 85           419072007  Amphotericin B (lipid formulation) 50mg/10ml s...
# 86    8062011000001106  Amphotericin B (lipid formulation) 100mg powde...
# 87           347535007  Amphotericin (liposomal) 50mg powder for solut...
# 88           324653006  Amphotericin 50mg/10ml suspension for injectio...
# 89   41871911000001103  Amphotericin B 50mg powder for solution for in...
# 90   21199311000001102  Amphotericin B sodium cholesteryl sulfate comp...
# 91   21199211000001105  Amphotericin B liposomal 50mg powder for dispe...
# 92   21199411000001109  Amphotericin B sodium cholesteryl sulfate comp...
# 93   36038311000001105  Leuprorelin 3.75mg powder and solvent for susp...
# 94   36038211000001102  Leuprorelin 11.25mg powder and solvent for sus...
# 95   19306211000001104  Leuprorelin 3.75mg powder and solvent for prol...
# 96   19306111000001105  Leuprorelin 11.25mg powder and solvent for pro...
# 97   30806811000001103  Leuprorelin 22.5mg powder and solvent for susp...
# 98   30806811000001103  Leuprorelin 22.5mg powder and solvent for susp...
# 99   42978711000001102  Leuprorelin 1.88mg powder and solvent for prol...
# 100  18468411000001108  Triptorelin embonate 11.25mg powder and solven...
# 101  36145411000001101  Triptorelin acetate 3mg powder and solvent for...
# 102  36145311000001108  Triptorelin acetate 3.75mg powder and solvent ...
# 103  36145111000001106  Triptorelin 11.25mg powder and solvent for pro...
# 104  18496811000001106  Triptorelin embonate 22.5mg powder and solvent...
# 105  42011111000001106                   Dextropropoxyphene 60mg capsules
# 106  32879311000001102        Pizotifen 500micrograms/5ml oral suspension
# 107  34378711000001104        Pizotifen 750micrograms/5ml oral suspension
# 108  32638611000001106              Topiramate 62.5mg/5ml oral suspension
# 109  36053511000001109  Haloperidol 5mg/1ml solution for injection amp...
# 110  36053711000001104  Haloperidol decanoate 50mg/1ml solution for in...
# 111  36053611000001108  Haloperidol decanoate 100mg/1ml solution for i...
# 112  36053411000001105  Haloperidol 20mg/2ml solution for injection am...
# 113  36152111000001102  Zuclopenthixol decanoate 200mg/1ml solution fo...
# 114  36152211000001108  Zuclopenthixol decanoate 500mg/1ml solution fo...
# 115  13456411000001100  Aripiprazole 9.75mg/1.3ml solution for injecti...
# 116  23661211000001102  Aripiprazole 400mg powder and solvent for prol...
# 117  31087211000001107  Aripiprazole 400mg powder and solvent for prol...
# 118  42826411000001100  Aripiprazole 960mg/3.2ml prolonged-release sus...
# 119  42880111000001103  Aripiprazole 720mg/2.4ml prolonged-release sus...
# 120  19611011000001106  Midazolam maleate 10mg/1ml oromucosal solution...
# 121   9479011000001103  Tiotropium bromide 18microgram inhalation powd...
# 122   9478911000001107  Tiotropium bromide 18microgram inhalation powd...
# 123  33596311000001107  Tiotropium bromide 10microgram inhalation powd...
#
#         who_route      atc  dmd_DDD    dmd_UOM  dmd_DDD_matched  \
# 0               O  A07EA06     1.50         mg            1.500
# 1               O  A07EA06     1.50         mg            1.500
# 2               O  A10BB01    10.00         mg           10.000
# 3               O  A10BB01    10.00         mg           10.000
# 4               O  A10BB01    10.00         mg           10.000
# 5               O  A10BB01    10.00         mg           10.000
# 6               O  A10BB01    10.00         mg           10.000
# 7               O  A10BB01    10.00         mg           10.000
# 8               O  A10BB01     7.00         mg            7.000
# 9               O  A10BB01     7.00         mg            7.000
# 10              O  A10BB01     7.00         mg            7.000
# 11              O  A10BB01     7.00         mg            7.000
# 12              O  A10BB01    10.00         mg           10.000
# 13              O  A10BB01    10.00         mg           10.000
# 14              O  A10BB01    10.00         mg           10.000
# 15              O  A10BB01    10.00         mg           10.000
# 16              P  A10BJ01    15.00  microgram            0.015
# 17              P  A10BJ01    15.00  microgram            0.015
# 18              P  A10BJ01   286.00  microgram          286.000
# 19              P  A10BJ01   286.00  microgram          286.000
# 20              P  A10BJ01   286.00  microgram          286.000
# 21              O  A12CD01     1.10         mg            1.100
# 22              O  A12CD01     1.10         mg            1.100
# 23              O  A12CD01     1.10         mg            1.100
# 24              O  A12CD01     1.10         mg            1.100
# 25             SL  C01DA02     5.00         mg            5.000
# 26             SL  C01DA02     5.00         mg            5.000
# 27             SL  C01DA02     5.00         mg            5.000
# 28             SL  C01DA02     5.00         mg            5.000
# 29             SL  C01DA02     5.00         mg            5.000
# 30             SL  C01DA02     5.00         mg            5.000
# 31             SL  C01DA02     5.00         mg            5.000
# 32             TD  C01DA08    20.00         mg            0.020
# 33              P  C04AB01     1.00         mg            1.000
# 34             TD  G03BA03     3.00         mg            3.000
# 35             TD  G03BA03     3.00         mg            3.000
# 36             TD  G03BA03     3.00         mg            3.000
# 37             TD  G03BA03    50.00         mg           50.000
# 38             TD  G03BA03    50.00         mg           50.000
# 39             TD  G03BA03    50.00         mg           50.000
# 40             TD  G03BA03     3.00         mg            3.000
# 41             TD  G03BA03    50.00         mg           50.000
# 42             TD  G03BA03    50.00         mg           50.000
# 43             TD  G03BA03    50.00         mg           50.000
# 44             TD  G03BA03    50.00         mg           50.000
# 45              V  G03CA03    25.00  microgram           25.000
# 46             TD  G03CA03    50.00  microgram            0.050
# 47             TD  G03CA03    50.00  microgram            0.050
# 48             TD  G03CA03    50.00  microgram            0.050
# 49             TD  G03CA03    50.00  microgram            0.050
# 50             TD  G03CA03    50.00  microgram            0.050
# 51             TD  G03CA03    50.00  microgram            0.050
# 52             TD  G03CA03    50.00  microgram            0.050
# 53             TD  G03CA03    50.00  microgram            0.050
# 54             TD  G03CA03    50.00  microgram            0.050
# 55             TD  G03CA03    50.00  microgram            0.050
# 56             TD  G03CA03    50.00  microgram            0.050
# 57             TD  G03CA03    50.00  microgram            0.050
# 58             TD  G03CA03    50.00  microgram            0.050
# 59             TD  G03CA03    50.00  microgram            0.050
# 60             TD  G03CA03     1.00         mg         1000.000
# 61             TD  G03CA03     1.00         mg            1.000
# 62             TD  G03CA03     1.00         mg         1000.000
# 63             TD  G03CA03     1.00         mg            1.000
# 64             TD  G03CA03     1.00         mg         1000.000
# 65             TD  G03CA03     1.00         mg            1.000
# 66              V  G03CA03    25.00  microgram           25.000
# 67              V  G03CA03     7.50  microgram            7.500
# 68             TD  G03CA03     1.53         mg         1530.000
# 69             TD  G03CA03     1.53         mg            1.530
# 70              O  G03CA04     5.00         mg            5.000
# 71              P  H02AB01     1.50         mg            1.500
# 72              O  J01FA01     2.00       gram            2.000
# 73              O  J01FA01     2.00       gram            2.000
# 74              O  J01FA01     1.00       gram            1.000
# 75              O  J01FA01     1.00       gram            1.000
# 76              O  J01FA01     1.00       gram            1.000
# 77              O  J01FA01     1.00       gram            1.000
# 78              O  J01FA01     2.00       gram            2.000
# 79              O  J01FA01     2.00       gram            2.000
# 80              O  J01FA01     2.00       gram            2.000
# 81              O  J01FA01     2.00       gram            2.000
# 82              O  J01FA01     2.00       gram            2.000
# 83              O  J01XX05     2.00       gram            2.000
# 84              P  J02AA01    35.00         mg           35.000
# 85              P  J02AA01    35.00         mg           35.000
# 86              P  J02AA01    35.00         mg           35.000
# 87              P  J02AA01    35.00         mg           35.000
# 88              P  J02AA01    35.00         mg           35.000
# 89              P  J02AA01    35.00         mg           35.000
# 90              P  J02AA01    35.00         mg           35.000
# 91              P  J02AA01    35.00         mg           35.000
# 92              P  J02AA01    35.00         mg           35.000
# 93              P  L02AE02   134.00  microgram            0.134
# 94              P  L02AE02   134.00  microgram            0.134
# 95              P  L02AE02   134.00  microgram            0.134
# 96              P  L02AE02   134.00  microgram            0.134
# 97              P  L02AE02   134.00         mg          134.000
# 98              P  L02AE02   134.00         mg          134.000
# 99              P  L02AE02   134.00  microgram            0.134
# 100             P  L02AE04   134.00  microgram            0.134
# 101             P  L02AE04   134.00  microgram            0.134
# 102             P  L02AE04   134.00  microgram            0.134
# 103             P  L02AE04   134.00  microgram            0.134
# 104             P  L02AE04   134.00  microgram            0.134
# 105             O  N02AC04   300.00         mg            0.300
# 106             O  N02CX01   150.00  microgram            0.150
# 107             O  N02CX01   150.00  microgram            0.150
# 108             O  N03AX11   100.00         mg            0.100
# 109             P  N05AD01     8.00         mg            8.000
# 110             P  N05AD01     3.30         mg            3.300
# 111             P  N05AD01     3.30         mg            3.300
# 112             P  N05AD01     8.00         mg            8.000
# 113             P  N05AF05    15.00         mg           15.000
# 114             P  N05AF05    15.00         mg           15.000
# 115             P  N05AX12    15.00         mg           15.000
# 116             P  N05AX12    13.30         mg           13.300
# 117             P  N05AX12    13.30         mg           13.300
# 118             P  N05AX12    13.30         mg           13.300
# 119             P  N05AX12    13.30         mg           13.300
# 120            SL  N05CD08    15.00         mg           15.000
# 121  Inhal.powder  R03BB04    18.00  microgram           18.000
# 122  Inhal.powder  R03BB04    18.00  microgram           18.000
# 123  Inhal.powder  R03BB04    18.00  microgram           18.000
#
#     dmd_UOM_matched  who_ddd who_UOM  \
# 0                mg    9.000      mg
# 1                mg    9.000      mg
# 2                mg    7.000      mg
# 3                mg    7.000      mg
# 4                mg    7.000      mg
# 5                mg    7.000      mg
# 6                mg    7.000      mg
# 7                mg    7.000      mg
# 8                mg   10.000      mg
# 9                mg   10.000      mg
# 10               mg   10.000      mg
# 11               mg   10.000      mg
# 12               mg    7.000      mg
# 13               mg    7.000      mg
# 14               mg    7.000      mg
# 15               mg    7.000      mg
# 16               mg    0.286      mg
# 17               mg    0.286      mg
# 18              mcg   15.000     mcg
# 19              mcg   15.000     mcg
# 20              mcg   15.000     mcg
# 21               mg   88.000      mg
# 22               mg   88.000      mg
# 23               mg   88.000      mg
# 24               mg   88.000      mg
# 25               mg    2.500      mg
# 26               mg    2.500      mg
# 27               mg    2.500      mg
# 28               mg    2.500      mg
# 29               mg    2.500      mg
# 30               mg    2.500      mg
# 31               mg    2.500      mg
# 32                g    0.100       g
# 33               mg   10.000      mg
# 34               mg   50.000      mg
# 35               mg   50.000      mg
# 36               mg   50.000      mg
# 37               mg    3.000      mg
# 38               mg    3.000      mg
# 39               mg    3.000      mg
# 40               mg   50.000      mg
# 41               mg    3.000      mg
# 42               mg    3.000      mg
# 43               mg    3.000      mg
# 44               mg    3.000      mg
# 45              mcg    7.500     mcg
# 46               mg    1.000      mg
# 47               mg    1.530      mg
# 48               mg    1.000      mg
# 49               mg    1.530      mg
# 50               mg    1.000      mg
# 51               mg    1.530      mg
# 52               mg    1.000      mg
# 53               mg    1.530      mg
# 54               mg    1.000      mg
# 55               mg    1.530      mg
# 56               mg    1.000      mg
# 57               mg    1.530      mg
# 58               mg    1.000      mg
# 59               mg    1.530      mg
# 60              mcg   50.000     mcg
# 61               mg    1.530      mg
# 62              mcg   50.000     mcg
# 63               mg    1.530      mg
# 64              mcg   50.000     mcg
# 65               mg    1.530      mg
# 66              mcg    7.500     mcg
# 67              mcg   25.000     mcg
# 68              mcg   50.000     mcg
# 69               mg    1.000      mg
# 70               mg    2.000      mg
# 71               mg    0.400      mg
# 72                g    1.000       g
# 73                g    1.000       g
# 74                g    2.000       g
# 75                g    2.000       g
# 76                g    2.000       g
# 77                g    2.000       g
# 78                g    1.000       g
# 79                g    1.000       g
# 80                g    1.000       g
# 81                g    1.000       g
# 82                g    1.000       g
# 83                g    3.000       g
# 84               mg  210.000      mg
# 85               mg  210.000      mg
# 86               mg  210.000      mg
# 87               mg  210.000      mg
# 88               mg  210.000      mg
# 89               mg  210.000      mg
# 90               mg  210.000      mg
# 91               mg  210.000      mg
# 92               mg  210.000      mg
# 93               mg    1.000      mg
# 94               mg    1.000      mg
# 95               mg    1.000      mg
# 96               mg    1.000      mg
# 97               mg    1.000      mg
# 98               mg    0.134      mg
# 99               mg    1.000      mg
# 100              mg    0.100      mg
# 101              mg    0.100      mg
# 102              mg    0.100      mg
# 103              mg    0.100      mg
# 104              mg    0.100      mg
# 105               g    0.200       g
# 106              mg    1.500      mg
# 107              mg    1.500      mg
# 108               g    0.300       g
# 109              mg    3.300      mg
# 110              mg    8.000      mg
# 111              mg    8.000      mg
# 112              mg    3.300      mg
# 113              mg   30.000      mg
# 114              mg   30.000      mg
# 115              mg   13.300      mg
# 116              mg   15.000      mg
# 117              mg   15.000      mg
# 118              mg   15.000      mg
# 119              mg   15.000      mg
# 120              mg   10.000      mg
# 121             mcg   10.000     mcg
# 122             mcg   10.000     mcg
# 123             mcg   10.000     mcg
#
#                                        who_ddd_comment
# 0                                                 None
# 1                                                 None
# 2                                 microcryst.substance
# 3                                 microcryst.substance
# 4                                 microcryst.substance
# 5                                 microcryst.substance
# 6                                 microcryst.substance
# 7                                 microcryst.substance
# 8                                                 None
# 9                                                 None
# 10                                                None
# 11                                                None
# 12                                microcryst.substance
# 13                                microcryst.substance
# 14                                microcryst.substance
# 15                                microcryst.substance
# 16                                           depot inj
# 17                                           depot inj
# 18
# 19
# 20
# 21                                      40 mg fluoride
# 22                                      40 mg fluoride
# 23                                      40 mg fluoride
# 24                                      40 mg fluoride
# 25                                                None
# 26                                                None
# 27                                                None
# 28                                                None
# 29                                                None
# 30                                                None
# 31                                                None
# 32                                                None
# 33                                                None
# 34                                                gel
# 35                                                gel
# 36                                                gel
# 37                                                None
# 38                                                None
# 39                                                None
# 40                                                gel
# 41                                                None
# 42                                                None
# 43                                                None
# 44                                                None
# 45   vaginal ring,  refers to amount delivered per ...
# 46                                                gel
# 47                                               spray
# 48                                                gel
# 49                                               spray
# 50                                                gel
# 51                                               spray
# 52                                                gel
# 53                                               spray
# 54                                                gel
# 55                                               spray
# 56                                                gel
# 57                                               spray
# 58                                                gel
# 59                                               spray
# 60       patch, refer to amount delivered per 24 hours
# 61                                               spray
# 62       patch, refer to amount delivered per 24 hours
# 63                                               spray
# 64       patch, refer to amount delivered per 24 hours
# 65                                               spray
# 66   vaginal ring,  refers to amount delivered per ...
# 67                                                None
# 68       patch, refer to amount delivered per 24 hours
# 69                                                gel
# 70                                                None
# 71                                               depot
# 72                                                None
# 73                                                None
# 74                 erythromycin ethylsuccinate tablets
# 75                 erythromycin ethylsuccinate tablets
# 76                 erythromycin ethylsuccinate tablets
# 77                 erythromycin ethylsuccinate tablets
# 78                                                None
# 79                                                None
# 80                                                None
# 81                                                None
# 82                                                None
# 83                                           mandelate
# 84                                  lipid formulations
# 85                                  lipid formulations
# 86                                  lipid formulations
# 87                                  lipid formulations
# 88                                  lipid formulations
# 89                                  lipid formulations
# 90                                  lipid formulations
# 91                                  lipid formulations
# 92                                  lipid formulations
# 93                                                None
# 94                                                None
# 95                                                None
# 96                                                None
# 97                                                None
# 98                                           depot inj
# 99                                                None
# 100                                               None
# 101                                               None
# 102                                               None
# 103                                               None
# 104                                               None
# 105                                           chloride
# 106                                               None
# 107                                               None
# 108                                               None
# 109                                              depot
# 110                                               None
# 111                                               None
# 112                                              depot
# 113                                               None
# 114                                               None
# 115                                              depot
# 116                                               None
# 117                                               None
# 118                                               None
# 119                                               None
# 120                                               None
# 121            Expressed as tiotropium, delivered dose
# 122            Expressed as tiotropium, delivered dose
# 123            Expressed as tiotropium, delivered dose

# %%
ddd_joined_unmatched.to_csv('ddd_joined_unmatched.csv')

# %% [markdown]
# ---
#
# ### Next steps

# %% [markdown]
# #### Improve mapping
# Identify reasons for unmatched rows.
#
# Review and identify the relevent WHO DDD comments which will affect calculations - e.g. Amphotericin B - we need to split by liposomal and non-liposomal.
#
# Look to manually map these issues

# %% [markdown]
# #### Look for unmatched
#
# Identify rows with dm+d DDDs that we haven't matched to WHO DDD
#
# Identify rows with WHO DDDs that we haven't matched to dm+d DDDs

# %% [markdown]
# #### Improve route matching
#
# Review in more detail how we match and identify / review in more detail the borderline/complex cases.
